# %%
# Importation des bibliothèques nécessaires
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Configuration pour les graphiques
# %matplotlib inline
plt.style.use('seaborn-v0_8-darkgrid')


# Bibliothèque pour la lecture des fichiers Excel
# !pip install openpyxl
import openpyxl

# Optionnel : affichage de toutes les colonnes du DataFrame
pd.set_option('display.max_columns', None)

# Optionnel : ajustement de la largeur des colonnes pour un meilleur affichage
pd.set_option('display.max_colwidth', None)

# Optionnel : pour augmenter la limite de lignes affichées dans les outputs du notebook
pd.set_option('display.max_rows', 500)
# Out:
# Requirement already satisfied: openpyxl in /opt/conda/lib/python3.11/site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in /opt/conda/lib/python3.11/site-packages (from openpyxl) (1.1.0)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

file_path = '/home/jovyan/work/indicateurs-annuels-cvs-mars22.xlsx'

df = pd.read_excel(file_path, header=7)

df.head()
# Out:
#                                                                      INDICATEURS/PERIODE  \
# 0  nombre de cambriolages et tentatives de cambriolage visant les résidences principales
# 1                       nombre de vols sans effraction visant les résidences principales
# 2                                        nombre d'actes de vandalisme contre le logement
# 3                                        nombre de vols et tentatives de vols de voiture
# 4                            nombre de vols et tentatives de vols de deux-roues à moteur
#
#      2006     2007     2008     2009     2010     2011     2012     2013  \
# 0  451000   438000   386000   413000   457000   554000   559000   584000
# 1  280000   335000   275000   323000   302000   296000   287000   254000
# 2  949000  1154000  1233000  1507000  1420000  1453000  1241000  1283000
# 3  570000   482000   456000   397000   395000   294000   270000   294000
# 4  145000   117000   102000   164000    96000   142000    77000   134000
#
#       2014     2015     2016    2017     2018 2019    2020 2021
# 0   602000   536000   507000  624000   557000  NaN  379000  NaN
# 1   307000   320000   277000  289000   331000  NaN  181000  NaN
# 2  1273000  1307000  1117000  966000  1184000  NaN  980000  NaN
# 3   242000   263000   263000  232000   209000  NaN  125000  NaN
# 4    83000   126000    93000   72000    44000  NaN     NaN  NaN

# %% [markdown]
# ##  Nettoyage des données: Remplacement des valeurs NaN par 0

# %%
df.fillna(0, inplace=True)

for col in df.columns[1:]:
    df[col] = pd.to_numeric(df[col].astype(str).str.replace(' ', ''), errors='coerce')

# %%
def plot_trend(df, row_index):
    plt.figure(figsize=(10, 5))
    plt.plot(df.columns[1:], df.iloc[row_index, 1:], marker='o')
    plt.title(df.iloc[row_index, 0])
    plt.xlabel('Année')
    plt.ylabel('Nombre')
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.show()

# %%
# Cambriolages et tentatives de cambriolage
plot_trend(df, 0)

# Vols sans effraction
plot_trend(df, 1)

# Actes de vandalisme contre le logement
plot_trend(df, 2)

# Vols et tentatives de vols de voiture
plot_trend(df, 3)

# Vols et tentatives de vols de deux-roues à moteur
plot_trend(df, 4)

# Vols et tentatives de vol de vélo
plot_trend(df, 5)

# Vols d'objet dans ou sur la voiture
plot_trend(df, 6)

# Actes de vandalisme contre la voiture
plot_trend(df, 7)

# Victimes de vols ou tentatives de vols sans violences ni menaces
plot_trend(df, 8)

# Victimes de vols ou tentatives de vols avec violences ou menaces
plot_trend(df, 9)

plot_trend(df, 10)

plot_trend(df, 11)

plot_trend(df, 12)

plot_trend(df, 13)

plot_trend(df, 14)

plot_trend(df, 15)

plot_trend(df, 16)

plot_trend(df, 17)

plot_trend(df, 18)

# %%
plt.figure(figsize=(12, 6))
for row_index in [0, 1, 3]:  # Exemple : Cambriolages, vols sans effraction, vols de voiture
    plt.plot(df.columns[1:], df.iloc[row_index, 1:], marker='o', label=df.iloc[row_index, 0])
plt.xlabel('Année')
plt.ylabel('Nombre')
plt.title('Comparaison des Tendances de Différents Indicateurs')
plt.legend()
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
print("Données manquantes pour 2019:", df[2019].isna().sum())
print("Données manquantes pour 2021:", df[2021].isna().sum())
# Out:
# Données manquantes pour 2019: 0
# Données manquantes pour 2021: 0
